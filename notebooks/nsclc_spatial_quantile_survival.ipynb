# %% [markdown]
# # NSCLC Spatial Tertile Survival Analysis
#
# This notebook follows the Figure 6 setup from `manuscript-figures.ipynb`: flatten ROI-level non-tumor spatial interaction matrices, merge clinical survival data, aggregate ROI-level interaction features to patient level, then test survival associations.
#
# Only the `tertile_even` strategy is kept here. For every directional interaction feature, available patients are split into three nearly equal rank-based groups: low, middle, and high.
#
# The tertile groups are used only to screen candidate interaction variables with KM/log-rank analysis. The adjusted Cox model uses the raw continuous spatial interaction index for the selected feature, not the tertile group assignment.
#
# No figures or result tables are saved by this notebook. All outputs are displayed in-memory only.

# %%
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multitest import multipletests
from lifelines.statistics import multivariate_logrank_test
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.exceptions import ConvergenceError

try:
    from IPython.display import display
except ImportError:
    def display(obj):
        print(obj)

warnings.filterwarnings("ignore", category=RuntimeWarning)
pd.set_option("display.max_columns", 80)
sns.set_theme(style="whitegrid")

cwd = Path.cwd().resolve()
if cwd.name == "notebooks" and cwd.parent.name == "multiTAP":
    PROJECT_ROOT = cwd.parents[1]
elif (cwd / "multiTAP" / "notebooks").exists():
    PROJECT_ROOT = cwd
else:
    PROJECT_ROOT = Path("/project/Xie_Lab/zgu/xiao_multiplex")

WORK_DIR = PROJECT_ROOT / "nsclc_multiTAP_work"
ACCUMUL_TYPE = "sum"
K_NEIGHBORS = 15
SPATIAL_PATH = WORK_DIR / f"nontumor_spatial_kneighbor{K_NEIGHBORS}_{ACCUMUL_TYPE}.csv"
CLINICAL_PATH = WORK_DIR / "clinical_data_ROI.csv"

FDR_ALPHA = 0.05
MINIMUM_PT_THRESH_FRAC = 0.10
MINIMUM_GROUP_SIZE_FRAC_OF_PT_THRESH = 0.30
MINIMUM_GROUP_EVENTS_FRAC_OF_GROUP_SIZE = 0.30

print(f"PROJECT_ROOT = {PROJECT_ROOT}")
print(f"SPATIAL_PATH = {SPATIAL_PATH}")
print(f"CLINICAL_PATH = {CLINICAL_PATH}")
# Out:
# PROJECT_ROOT = /project/Xie_Lab/zgu/xiao_multiplex
# SPATIAL_PATH = /project/Xie_Lab/zgu/xiao_multiplex/nsclc_multiTAP_work/nontumor_spatial_kneighbor15_sum.csv
# CLINICAL_PATH = /project/Xie_Lab/zgu/xiao_multiplex/nsclc_multiTAP_work/clinical_data_ROI.csv

# %% [markdown]
# ## Figure 6 Setup Helpers

# %%
def flatten_interaction_matrix(df: pd.DataFrame) -> pd.DataFrame:
    """Flatten a square directional spatial interaction matrix into one wide row."""
    if df.shape[0] != df.shape[1]:
        raise ValueError("Input DataFrame must be square.")
    if not df.columns.equals(df.index):
        raise ValueError("DataFrame must have matching row and column labels.")
    colnames = [f"{row}_to_{col}" for row in df.index for col in df.columns]
    return pd.DataFrame([df.to_numpy().flatten()], columns=colnames)


def extract_roi_id(roi_id):
    try:
        split = roi_id.split("_")
        if roi_id.startswith("178_A") or roi_id.startswith("178_C"):
            return f"{split[0]}_{split[2]}{split[3]},{split[4]}"
        if roi_id.startswith("178_B"):
            return f"{split[0]}_{split[3]}{split[4]},{split[5]}"
        return f"{split[0]}_{split[2]},{split[3]}"
    except IndexError:
        return None


cell_type_cols = [
    "final_cell_type_B cells", "final_cell_type_CD4", "final_cell_type_CD4 Treg",
    "final_cell_type_CD8", "final_cell_type_Collagen CAF", "final_cell_type_IDO_CD4",
    "final_cell_type_IDO_CD8", "final_cell_type_IFN CAF", "final_cell_type_Ki67_CD4",
    "final_cell_type_Ki67_CD8", "final_cell_type_PD1 CD4", "final_cell_type_PDPN CAF",
    "final_cell_type_SMA CAF", "final_cell_type_TCF1/7 CD4", "final_cell_type_TCF1/7 CD8",
    "final_cell_type_dCAF", "final_cell_type_endothelial",
    "final_cell_type_high endothelial venules (HEV)", "final_cell_type_hypoxic CAF",
    "final_cell_type_hypoxic tCAF", "final_cell_type_iCAF", "final_cell_type_lymphatic endothelial",
    "final_cell_type_mCAF", "final_cell_type_myeloid", "final_cell_type_neutrophils",
    "final_cell_type_tCAF", "final_cell_type_vCAF",
]

# %% [markdown]
# ## Load And Flatten ROI-Level Spatial Interactions

# %%
spatial_pt_df = pd.read_csv(SPATIAL_PATH, index_col=0)
print(f"{spatial_pt_df['roi_id'].nunique()} ROIs identified before flattening")

spatial_pt_df = spatial_pt_df.reset_index(names="cell_type")
spatial_pt_df = spatial_pt_df.replace(0, np.nan)

flat_marker_roi_list = []
for roi_id in np.unique(spatial_pt_df["roi_id"]):
    try:
        one_spatial_mat = spatial_pt_df.loc[spatial_pt_df["roi_id"] == roi_id].copy()
        one_spatial_mat = one_spatial_mat.set_index("cell_type").drop(columns="roi_id")
        flat_roi = flatten_interaction_matrix(one_spatial_mat)
        flat_roi["ROI_ID"] = roi_id
        flat_marker_roi_list.append(flat_roi)
    except Exception as exc:
        print(f"ROI {roi_id} not processed due to error: {exc}")

combined_df = pd.concat(flat_marker_roi_list, axis=0, ignore_index=True)
combined_df["roi_mappable"] = combined_df["ROI_ID"].str.replace("NSCLC_ALL_", "", regex=False).apply(extract_roi_id)
print("flattened ROI-feature table:", combined_df.shape)
display(combined_df.head())
# Out:
# 1950 ROIs identified before flattening
# flattened ROI-feature table: (1950, 731)
#    final_cell_type_B cells_to_final_cell_type_B cells  \
# 0                                           0.130844
# 1                                                NaN
# 2                                                NaN
# 3                                          -0.224310
# 4                                          -0.263809
#
#    final_cell_type_B cells_to_final_cell_type_CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_B cells_to_final_cell_type_CD4 Treg  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_CD8  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                       -0.443824
#
#    final_cell_type_B cells_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.163243
# 3                                          -0.394078
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IDO_CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IDO_CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IFN CAF  \
# 0                                          -0.018393
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_Ki67_CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_Ki67_CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          -0.506835
#
#    final_cell_type_B cells_to_final_cell_type_PD1 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_PDPN CAF  \
# 0                                          -0.207670
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          -0.805821
#
#    final_cell_type_B cells_to_final_cell_type_SMA CAF  \
# 0                                          -0.421058
# 1                                                NaN
# 2                                          -0.664696
# 3                                          -0.548350
# 4                                          -0.419674
#
#    final_cell_type_B cells_to_final_cell_type_TCF1/7 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_TCF1/7 CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_dCAF  \
# 0                                        -0.604284
# 1                                              NaN
# 2                                              NaN
# 3                                        -1.025984
# 4                                        -0.834258
#
#    final_cell_type_B cells_to_final_cell_type_endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                          -0.508473
# 4                                          -0.391643
#
#    final_cell_type_B cells_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_hypoxic CAF  \
# 0                                          -0.640915
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_iCAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                        -0.009259
#
#    final_cell_type_B cells_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_mCAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        -0.309102
# 4                                        -0.306815
#
#    final_cell_type_B cells_to_final_cell_type_myeloid  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           0.063561
# 4                                          -0.645134
#
#    final_cell_type_B cells_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           0.352741
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_tCAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_B cells_to_final_cell_type_vCAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                         0.792970
# 3                                        -1.047705
# 4                                        -1.148835
#
#    final_cell_type_CD4_to_final_cell_type_B cells  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD4  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD4 Treg  \
# 0                                              NaN
# 1                                              NaN
# 2                                         1.144257
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD8  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    final_cell_type_CD4_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_CD4_to_final_cell_type_IDO_CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_IDO_CD8  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_IFN CAF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_Ki67_CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_Ki67_CD8  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_PD1 CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_PDPN CAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_SMA CAF  ...  \
# 0                                             NaN  ...
# 1                                             NaN  ...
# 2                                       -0.349001  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
#
#    final_cell_type_tCAF_to_final_cell_type_endothelial  \
# 0                                                NaN
# 1                                          -0.302569
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_hypoxic CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_iCAF  \
# 0                                      0.752470
# 1                                     -0.815796
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_tCAF_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_mCAF  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_tCAF_to_final_cell_type_myeloid  \
# 0                                         0.241496
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_tCAF_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_tCAF  \
# 0                                      0.767365
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_tCAF_to_final_cell_type_vCAF  \
# 0                                           NaN
# 1                                      0.064503
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_B cells  \
# 0                                              NaN
# 1                                              NaN
# 2                                         0.792970
# 3                                        -1.047705
# 4                                        -1.148835
#
#    final_cell_type_vCAF_to_final_cell_type_CD4  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    final_cell_type_vCAF_to_final_cell_type_CD4 Treg  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_CD8  \
# 0                                          NaN
# 1                                    -0.417297
# 2                                    -0.419706
# 3                                          NaN
# 4                                    -0.741565
#
#    final_cell_type_vCAF_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.255384
# 3                                          -0.687639
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_IDO_CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_IDO_CD8  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_IFN CAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        -0.101012
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_Ki67_CD4  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_Ki67_CD8  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_PD1 CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_PDPN CAF  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_SMA CAF  \
# 0                                              NaN
# 1                                        -0.306752
# 2                                        -0.222766
# 3                                        -0.535138
# 4                                        -0.624186
#
#    final_cell_type_vCAF_to_final_cell_type_TCF1/7 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_TCF1/7 CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_dCAF  \
# 0                                           NaN
# 1                                     -0.792024
# 2                                           NaN
# 3                                     -1.072408
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_endothelial  \
# 0                                                NaN
# 1                                          -0.259769
# 2                                          -0.284519
# 3                                           0.009426
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_hypoxic CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_iCAF  \
# 0                                           NaN
# 1                                     -0.582133
# 2                                           NaN
# 3                                     -0.085458
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_mCAF  \
# 0                                           NaN
# 1                                     -0.198769
# 2                                     -0.523197
# 3                                      0.014740
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_myeloid  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        -0.237937
# 4                                        -0.641988
#
#    final_cell_type_vCAF_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -1.363546
# 3                                                NaN
# 4                                           0.220689
#
#    final_cell_type_vCAF_to_final_cell_type_tCAF  \
# 0                                           NaN
# 1                                      0.064503
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_vCAF                 ROI_ID  \
# 0                                           NaN   NSCLC_ALL_175_A_A1_1
# 1                                      0.673285  NSCLC_ALL_175_A_A1_10
# 2                                      0.389697  NSCLC_ALL_175_A_A1_11
# 3                                      0.228058  NSCLC_ALL_175_A_A1_12
# 4                                      0.088272  NSCLC_ALL_175_A_A1_13
#
#    roi_mappable
# 0      175_A1,1
# 1     175_A1,10
# 2     175_A1,11
# 3     175_A1,12
# 4     175_A1,13
#
# [5 rows x 731 columns]

# %% [markdown]
# ## Merge Clinical Data And Aggregate To Patient Level

# %%
pt_clinical_data = pd.read_csv(CLINICAL_PATH)
print(f"{pt_clinical_data['Patient_ID'].nunique()} unique subjects before filtering")

pt_clinical_data = pt_clinical_data.loc[pt_clinical_data["Patient_ID"] != "Control"].copy()
pt_clinical_data = pt_clinical_data.loc[~pt_clinical_data["NeoAdj"].isna()].copy()
pt_clinical_data = pt_clinical_data.loc[pt_clinical_data["NeoAdj"] != "NeoAdjuvantTherapy"].reset_index(drop=True)
print(f"{pt_clinical_data['Patient_ID'].nunique()} unique patients after clinical filtering")

survival_clinical_cols = ["RoiID", "Patient_ID", "OS", "DFS", "Ev.O", "DX.name"]
pt_clinical_survival = pt_clinical_data[survival_clinical_cols].drop_duplicates(keep="first").reset_index(drop=True)

spatial_clinical_merged = combined_df.merge(
    pt_clinical_survival,
    how="inner",
    left_on="roi_mappable",
    right_on="RoiID",
)
spatial_clinical_merged = spatial_clinical_merged.dropna(subset=["OS", "Ev.O"]).reset_index(drop=True)
print("unique patients after ROI/survival merge:", spatial_clinical_merged["Patient_ID"].nunique())
print("unique ROIs after ROI/survival merge:", spatial_clinical_merged["roi_mappable"].nunique())

marker_cols = list(spatial_clinical_merged.columns[spatial_clinical_merged.columns.str.contains("final_cell_type")])
keep_cols = marker_cols + ["OS", "Ev.O", "Patient_ID", "DX.name"]
spatial_clinical_for_survival = spatial_clinical_merged[keep_cols].copy()

tumor_type_conflicts = spatial_clinical_for_survival.groupby("Patient_ID")["DX.name"].nunique(dropna=False)
tumor_type_conflicts = tumor_type_conflicts[tumor_type_conflicts > 1]
print(f"Patients with ROI-level tumor type conflicts: {len(tumor_type_conflicts)}")

spatial_clinical_for_survival = spatial_clinical_for_survival.groupby("Patient_ID").agg(
    {**{col: "mean" for col in marker_cols + ["OS", "Ev.O"]}, "DX.name": "first"}
).reset_index()

minimum_pt_thresh = int(MINIMUM_PT_THRESH_FRAC * len(spatial_clinical_for_survival))
minimum_group_size = int(MINIMUM_GROUP_SIZE_FRAC_OF_PT_THRESH * minimum_pt_thresh)
minimum_group_events = int(MINIMUM_GROUP_EVENTS_FRAC_OF_GROUP_SIZE * minimum_group_size)

print("patient-level survival frame:", spatial_clinical_for_survival.shape)
print(f"minimum_pt_thresh={minimum_pt_thresh}, minimum_group_size={minimum_group_size}, minimum_group_events={minimum_group_events}")
display(spatial_clinical_for_survival.head())
# Out:
# 1071 unique subjects before filtering
# 959 unique patients after clinical filtering
# unique patients after ROI/survival merge: 953
# unique ROIs after ROI/survival merge: 1755
# Patients with ROI-level tumor type conflicts: 0
# patient-level survival frame: (953, 733)
# minimum_pt_thresh=95, minimum_group_size=28, minimum_group_events=8
#   Patient_ID  final_cell_type_B cells_to_final_cell_type_B cells  \
# 0      175_1                                           0.168452
# 1     175_10                                           0.124939
# 2    175_100                                           0.301903
# 3    175_101                                           0.342103
# 4    175_102                                           0.251555
#
#    final_cell_type_B cells_to_final_cell_type_CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_B cells_to_final_cell_type_CD4 Treg  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.121964
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_CD8  \
# 0                                             NaN
# 1                                             NaN
# 2                                       -0.559178
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_B cells_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.596081
# 3                                          -0.614548
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IDO_CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.096762
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IDO_CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.632213
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_IFN CAF  \
# 0                                          -0.018393
# 1                                                NaN
# 2                                          -0.104330
# 3                                          -0.794573
# 4                                          -0.617567
#
#    final_cell_type_B cells_to_final_cell_type_Ki67_CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                           -0.01922
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_Ki67_CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.944191
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_PD1 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.146784
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_PDPN CAF  \
# 0                                          -0.207670
# 1                                                NaN
# 2                                           0.390479
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_SMA CAF  \
# 0                                          -0.428995
# 1                                          -1.533343
# 2                                          -0.546604
# 3                                          -0.132361
# 4                                          -1.197442
#
#    final_cell_type_B cells_to_final_cell_type_TCF1/7 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_TCF1/7 CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_dCAF  \
# 0                                        -0.604284
# 1                                         0.320390
# 2                                              NaN
# 3                                        -0.471981
# 4                                        -0.965963
#
#    final_cell_type_B cells_to_final_cell_type_endothelial  \
# 0                                          -0.521906
# 1                                          -0.208294
# 2                                          -0.451990
# 3                                          -1.163331
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_hypoxic CAF  \
# 0                                          -0.825639
# 1                                                NaN
# 2                                          -0.686403
# 3                                          -0.214117
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                          -0.114342
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_iCAF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        -0.741150
# 4                                        -0.284921
#
#    final_cell_type_B cells_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.469399
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_mCAF  \
# 0                                        -0.732518
# 1                                              NaN
# 2                                        -0.569487
# 3                                        -0.134075
# 4                                              NaN
#
#    final_cell_type_B cells_to_final_cell_type_myeloid  \
# 0                                           0.091101
# 1                                           0.159555
# 2                                           0.074199
# 3                                          -0.276427
# 4                                          -0.846189
#
#    final_cell_type_B cells_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.288185
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_B cells_to_final_cell_type_tCAF  \
# 0                                              NaN
# 1                                         -0.51012
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_B cells_to_final_cell_type_vCAF  \
# 0                                        -0.759147
# 1                                        -0.401016
# 2                                        -0.567249
# 3                                         0.064313
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_B cells  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD4  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD4 Treg  \
# 0                                              NaN
# 1                                        -0.215563
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_CD8  \
# 0                                         NaN
# 1                                   -0.143232
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    final_cell_type_CD4_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                          -0.470462
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_CD4_to_final_cell_type_IDO_CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_IDO_CD8  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_IFN CAF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_Ki67_CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_Ki67_CD8  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_CD4_to_final_cell_type_PD1 CD4  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    final_cell_type_CD4_to_final_cell_type_PDPN CAF  ...  \
# 0                                              NaN  ...
# 1                                         0.120005  ...
# 2                                              NaN  ...
# 3                                              NaN  ...
# 4                                              NaN  ...
#
#    final_cell_type_tCAF_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_hypoxic CAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                          -0.423387
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_iCAF  \
# 0                                      0.752470
# 1                                     -0.852475
# 2                                           NaN
# 3                                     -0.073420
# 4                                     -0.822074
#
#    final_cell_type_tCAF_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_mCAF  \
# 0                                           NaN
# 1                                     -1.059417
# 2                                     -0.182425
# 3                                     -0.107566
# 4                                           NaN
#
#    final_cell_type_tCAF_to_final_cell_type_myeloid  \
# 0                                         0.241496
# 1                                        -0.478290
# 2                                              NaN
# 3                                        -0.908727
# 4                                              NaN
#
#    final_cell_type_tCAF_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                          -0.699917
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_tCAF_to_final_cell_type_tCAF  \
# 0                                      0.767365
# 1                                     -0.045026
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    final_cell_type_tCAF_to_final_cell_type_vCAF  \
# 0                                           NaN
# 1                                     -0.589232
# 2                                      0.132672
# 3                                           NaN
# 4                                     -1.073562
#
#    final_cell_type_vCAF_to_final_cell_type_B cells  \
# 0                                        -0.759147
# 1                                        -0.577107
# 2                                        -0.587452
# 3                                         0.064313
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_CD4  \
# 0                                          NaN
# 1                                          NaN
# 2                                     0.225539
# 3                                          NaN
# 4                                          NaN
#
#    final_cell_type_vCAF_to_final_cell_type_CD4 Treg  \
# 0                                               NaN
# 1                                         -0.372132
# 2                                         -0.489248
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_CD8  \
# 0                                          NaN
# 1                                    -0.965721
# 2                                    -0.326361
# 3                                          NaN
# 4                                          NaN
#
#    final_cell_type_vCAF_to_final_cell_type_Collagen CAF  \
# 0                                                NaN
# 1                                          -0.666653
# 2                                          -0.426930
# 3                                          -0.261936
# 4                                          -0.061879
#
#    final_cell_type_vCAF_to_final_cell_type_IDO_CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_IDO_CD8  \
# 0                                              NaN
# 1                                              NaN
# 2                                        -0.143993
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_IFN CAF  \
# 0                                              NaN
# 1                                        -0.781733
# 2                                        -0.734632
# 3                                        -0.809294
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_Ki67_CD4  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_Ki67_CD8  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_PD1 CD4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_PDPN CAF  \
# 0                                               NaN
# 1                                         -0.958397
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    final_cell_type_vCAF_to_final_cell_type_SMA CAF  \
# 0                                        -0.384259
# 1                                        -0.369021
# 2                                        -0.800397
# 3                                        -0.295963
# 4                                              NaN
#
#    final_cell_type_vCAF_to_final_cell_type_TCF1/7 CD4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_TCF1/7 CD8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_dCAF  \
# 0                                           NaN
# 1                                     -0.507933
# 2                                           NaN
# 3                                     -0.295650
# 4                                     -0.694113
#
#    final_cell_type_vCAF_to_final_cell_type_endothelial  \
# 0                                           0.043209
# 1                                          -0.674586
# 2                                           0.171628
# 3                                           0.188775
# 4                                           0.251071
#
#    final_cell_type_vCAF_to_final_cell_type_high endothelial venules (HEV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_hypoxic CAF  \
# 0                                          -0.744868
# 1                                                NaN
# 2                                          -0.310492
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_hypoxic tCAF  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.116051
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_iCAF  \
# 0                                      0.368047
# 1                                     -0.442446
# 2                                           NaN
# 3                                     -0.213500
# 4                                     -0.604280
#
#    final_cell_type_vCAF_to_final_cell_type_lymphatic endothelial  \
# 0                                                NaN
# 1                                                NaN
# 2                                           -0.06198
# 3                                                NaN
# 4                                                NaN
#
#    final_cell_type_vCAF_to_final_cell_type_mCAF  \
# 0                                     -0.467787
# 1                                     -0.189984
# 2                                     -0.487861
# 3                                     -0.627966
# 4                                           NaN
#
#    final_cell_type_vCAF_to_final_cell_type_myeloid  \
# 0                                        -0.572954
# 1                                        -0.302291
# 2                                        -0.536280
# 3                                         0.076574
# 4                                         0.070883
#
#    final_cell_type_vCAF_to_final_cell_type_neutrophils  \
# 0                                                NaN
# 1                                          -1.296232
# 2                                          -0.243848
# 3                                                NaN
# 4                                          -0.096921
#
#    final_cell_type_vCAF_to_final_cell_type_tCAF  \
# 0                                           NaN
# 1                                     -0.673553
# 2                                      0.132672
# 3                                           NaN
# 4                                     -1.073562
#
#    final_cell_type_vCAF_to_final_cell_type_vCAF      OS  Ev.O  \
# 0                                     -0.494354   254.0   1.0
# 1                                     -0.206097  1134.0   1.0
# 2                                      0.019130   490.0   1.0
# 3                                      0.109901  1930.0   1.0
# 4                                      0.201454   794.0   1.0
#
#                    DX.name
# 0           Adenocarcinoma
# 1           Adenocarcinoma
# 2  Squamous cell carcinoma
# 3  Squamous cell carcinoma
# 4  Squamous cell carcinoma
#
# [5 rows x 733 columns]

# %% [markdown]
# ## Quantile Grouping And Global Log-Rank Screen

# %%
QUANTILE_METHODS = {
    "tertile_even": "Three nearly equal groups using rank-based tertiles",
}


def assign_quantile_groups(values: pd.Series, method: str):
    if method != "tertile_even":
        raise ValueError(f"Unknown quantile method: {method}")

    values = values.astype(float)
    diagnostics = {
        "q33": values.quantile(1 / 3),
        "q50": values.quantile(0.50),
        "q67": values.quantile(2 / 3),
    }
    ranks = values.rank(method="first")
    groups = pd.qcut(ranks, q=3, labels=["low", "middle", "high"])
    return groups.astype("object"), diagnostics


def run_quantile_logrank_screen(data: pd.DataFrame, features, method: str = "tertile_even"):
    results = []
    skipped = []

    for feature in features:
        km_df = data[[feature, "OS", "Ev.O", "Patient_ID"]].dropna(subset=[feature, "OS", "Ev.O"]).copy()
        n_available = km_df.shape[0]
        if n_available < minimum_pt_thresh:
            skipped.append({"method": method, "feature": feature, "reason": "n_available", "n_available": n_available})
            continue
        if km_df[feature].nunique(dropna=True) < 3:
            skipped.append({"method": method, "feature": feature, "reason": "lt_3_unique_values", "n_available": n_available})
            continue

        km_df["quantile_group"], diagnostics = assign_quantile_groups(km_df[feature], method)
        counts = km_df["quantile_group"].value_counts().reindex(["low", "middle", "high"], fill_value=0)
        events = km_df.groupby("quantile_group")["Ev.O"].sum().reindex(["low", "middle", "high"], fill_value=0)

        if (counts <= 0).any():
            skipped.append({"method": method, "feature": feature, "reason": "missing_group", "n_available": n_available, **{f"n_{k}": v for k, v in counts.items()}})
            continue
        if counts.min() < minimum_group_size:
            skipped.append({"method": method, "feature": feature, "reason": "n_per_group", "n_available": n_available, **{f"n_{k}": v for k, v in counts.items()}})
            continue
        if events.min() < minimum_group_events:
            skipped.append({
                "method": method, "feature": feature, "reason": "events_per_group", "n_available": n_available,
                **{f"n_{k}": v for k, v in counts.items()},
                **{f"events_{k}": v for k, v in events.items()},
            })
            continue

        logrank_res = multivariate_logrank_test(km_df["OS"], km_df["quantile_group"], event_observed=km_df["Ev.O"])
        results.append({
            "method": method, "feature": feature, "n_available": n_available,
            "n_low": counts["low"], "n_middle": counts["middle"], "n_high": counts["high"],
            "events_low": events["low"], "events_middle": events["middle"], "events_high": events["high"],
            **diagnostics,
            "pval_logrank_global": logrank_res.p_value,
            "test_statistic": logrank_res.test_statistic,
        })

    results_df = pd.DataFrame(results)
    if not results_df.empty:
        results_df["pval_adj_bh"] = multipletests(results_df["pval_logrank_global"], method="fdr_bh")[1]
        results_df[f"bh_significant_{FDR_ALPHA:g}"] = results_df["pval_adj_bh"] < FDR_ALPHA
    return results_df, pd.DataFrame(skipped)

# %%
all_results = []
all_skipped = []

for method, description in QUANTILE_METHODS.items():
    print(f"Running {method}: {description}")
    method_results, method_skipped = run_quantile_logrank_screen(spatial_clinical_for_survival, marker_cols, method)
    all_results.append(method_results)
    all_skipped.append(method_skipped)
    print(f"  features tested: {method_results.shape[0]}")
    print(f"  features skipped: {method_skipped.shape[0]}")

quantile_results_df = pd.concat(all_results, ignore_index=True) if all_results else pd.DataFrame()
quantile_skipped_df = pd.concat(all_skipped, ignore_index=True) if all_skipped else pd.DataFrame()

if not quantile_results_df.empty:
    display(quantile_results_df.sort_values("pval_logrank_global").head(10))
if not quantile_skipped_df.empty:
    display(quantile_skipped_df.groupby(["method", "reason"]).size().to_frame("n_features"))
# Out:
# Running tertile_even: Three nearly equal groups using rank-based tertiles
#   features tested: 347
#   features skipped: 382
#            method                                            feature  \
# 305  tertile_even  final_cell_type_neutrophils_to_final_cell_type...
# 226  tertile_even  final_cell_type_hypoxic tCAF_to_final_cell_typ...
# 172  tertile_even  final_cell_type_dCAF_to_final_cell_type_hypoxi...
# 218  tertile_even  final_cell_type_hypoxic tCAF_to_final_cell_typ...
# 69   tertile_even  final_cell_type_Collagen CAF_to_final_cell_typ...
# 294  tertile_even  final_cell_type_neutrophils_to_final_cell_type...
# 125  tertile_even  final_cell_type_PDPN CAF_to_final_cell_type_hy...
# 20   tertile_even    final_cell_type_B cells_to_final_cell_type_vCAF
# 192  tertile_even  final_cell_type_endothelial_to_final_cell_type...
# 18   tertile_even  final_cell_type_B cells_to_final_cell_type_neu...
#
#      n_available  n_low  n_middle  n_high  events_low  events_middle  \
# 305          159     53        53      53        48.0           37.0
# 226          168     56        56      56        50.0           40.0
# 172          223     75        74      74        54.0           61.0
# 218          115     39        38      38        34.0           24.0
# 69           593    198       197     198       142.0          148.0
# 294          570    190       190     190       123.0          118.0
# 125          230     77        76      77        66.0           54.0
# 20           605    202       201     202       134.0          137.0
# 192          140     47        46      47        38.0           33.0
# 18           573    191       191     191       119.0          125.0
#
#      events_high       q33       q50       q67  pval_logrank_global  \
# 305         38.0 -0.525380 -0.310235 -0.111719             0.000007
# 226         38.0 -0.500582 -0.286396 -0.083539             0.001181
# 172         45.0 -0.626575 -0.515488 -0.374854             0.002283
# 218         21.0 -0.591459 -0.478165 -0.243522             0.002614
# 69         126.0 -0.528441 -0.400799 -0.261521             0.003149
# 294        150.0 -0.677786 -0.523890 -0.366993             0.003907
# 125         54.0 -0.770534 -0.498276 -0.364232             0.005445
# 20         156.0 -0.681500 -0.567686 -0.427533             0.006834
# 192         29.0 -0.586424 -0.402039 -0.254652             0.008462
# 18         148.0 -0.699539 -0.541814 -0.367150             0.008774
#
#      test_statistic  pval_adj_bh  bh_significant_0.05
# 305       23.886609     0.002256                 True
# 226       13.483629     0.204817                False
# 172       12.164964     0.218573                False
# 218       11.893961     0.218573                False
# 69        11.521043     0.218573                False
# 294       11.090223     0.225926                False
# 125       10.426072     0.269922                False
# 20         9.971578     0.296441                False
# 192        9.544359     0.304449                False
# 18         9.471985     0.304449                False
#                           n_features
# method       reason
# tertile_even n_available         382

# %% [markdown]
# ## Kaplan-Meier Curves For The Top Tertile Feature
#
# The three tertile groups are defined once in all eligible patients for the selected neutrophils-to-hypoxic-tCAF interaction. The all-patient panel reports both the nominal log-rank p-value and the Benjamini-Hochberg FDR q-value from the all-feature screen. LUAD and LUSC panels reuse the same all-patient tertile labels and report nominal subtype-restricted log-rank p-values.

# %%
FEATURE_LABELS = {
    "final_cell_type_neutrophils_to_final_cell_type_hypoxic tCAF": "Neutrophils vs. hypoxic tCAF",
}


def clean_feature_label(feature: str) -> str:
    if feature in FEATURE_LABELS:
        return FEATURE_LABELS[feature]
    label = feature.replace("final_cell_type_", "")
    label = label.replace("_to_", " vs. ")
    label = label.replace("_", " ")
    return label


GENDER_LEVEL_LABELS = {"1.0": "male", "2.0": "female"}
SMOKING_LEVEL_LABELS = {"0.0": "never smoker", "1.0": "current smoker", "2.0": "former smoker", "3.0": "smoking unknown"}
THERAPY_LEVEL_LABELS = {"0.0": "no", "1.0": "yes"}


def clean_dummy_level(raw_level: str, labels: dict) -> str:
    return labels.get(raw_level, raw_level.rstrip(".0"))


def clean_cox_variable_label(variable: str, feature: str) -> str:
    if variable == feature:
        return f"{clean_feature_label(feature)} interaction index"
    if variable.startswith("Gender_"):
        level = variable.split("_", 1)[1]
        return f"{clean_dummy_level(level, GENDER_LEVEL_LABELS)}"
    if variable.startswith("Smok_"):
        level = variable.split("_", 1)[1]
        return f"{clean_dummy_level(level, SMOKING_LEVEL_LABELS)}"
    if variable.startswith("Chemo_"):
        level = variable.split("_", 1)[1]
        return f"Neoadjuvant chemotherapy: {clean_dummy_level(level, THERAPY_LEVEL_LABELS)} vs. no"
    if variable.startswith("Radio_"):
        level = variable.split("_", 1)[1]
        return f"Neoadjuvant radiation: {clean_dummy_level(level, THERAPY_LEVEL_LABELS)} vs. no"
    return variable


def format_p_value(p_value):
    if pd.isna(p_value):
        return "NA"
    if p_value < 0.001:
        return f"{p_value:.1e}"
    return f"{p_value:.3f}"


def add_global_quantile_groups_for_feature(data: pd.DataFrame, feature: str, method: str):
    grouped_df = data[[feature, "OS", "Ev.O", "Patient_ID", "DX.name"]].dropna(subset=[feature, "OS", "Ev.O"]).copy()
    grouped_df["quantile_group"], diagnostics = assign_quantile_groups(grouped_df[feature], method)
    return grouped_df, diagnostics


def plot_km_quantile(ax, grouped_df, diagnostics, feature, title, tumor_type=None, q_value=None):
    km_df = grouped_df.copy()
    if tumor_type is not None:
        km_df = km_df.loc[km_df["DX.name"] == tumor_type].copy()

    if km_df.empty:
        ax.set_title(f"{title}\nno patients", fontsize=11, fontweight="bold")
        ax.axis("off")
        return {"cohort": title, "tumor_type": tumor_type or "All", "feature": feature, "n": 0, "filter_reason": "no_patients"}

    group_order = ["low", "middle", "high"]
    counts = km_df["quantile_group"].value_counts().reindex(group_order, fill_value=0)
    events = km_df.groupby("quantile_group")["Ev.O"].sum().reindex(group_order, fill_value=0)
    nonempty_groups = counts[counts > 0].index.tolist()

    deep = sns.color_palette("deep", 10)
    colors = {"low": deep[3], "middle": deep[7], "high": deep[9]}
    labels = {"low": "Low tertile", "middle": "Middle tertile", "high": "High tertile"}

    kmf = KaplanMeierFitter()
    for group in group_order:
        group_df = km_df.loc[km_df["quantile_group"] == group]
        if group_df.empty:
            continue
        kmf.fit(group_df["OS"], event_observed=group_df["Ev.O"], label=f"{labels[group]} (n={group_df.shape[0]})")
        kmf.plot(ax=ax, c=colors[group], linewidth=2.2, ci_show=True, ci_alpha=0.15)

    p_value = np.nan
    filter_reason = "tested"
    if len(nonempty_groups) >= 2:
        try:
            res = multivariate_logrank_test(km_df["OS"], km_df["quantile_group"], event_observed=km_df["Ev.O"])
            p_value = res.p_value
        except Exception as exc:
            filter_reason = f"logrank_error: {exc}"
    else:
        filter_reason = "single_nonempty_group"

    p_label = f"Nominal log-rank p = {format_p_value(p_value)}"
    if q_value is not None:
        p_label += f"; BH-FDR q = {format_p_value(q_value)}"

    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.text(0.02, 0.04, p_label, transform=ax.transAxes, ha="left", va="bottom", fontsize=9)
    ax.set_xlabel("Overall survival (days)")
    ax.set_ylabel("Survival probability")
    ax.set_ylim(-0.03, 1.03)
    ax.set_yticks([0, 0.25, 0.5, 0.75, 1])
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.legend(title="All-patient tertile", frameon=False, fontsize=9, title_fontsize=9)
    return {
        "cohort": title, "tumor_type": tumor_type or "All", "feature": feature,
        "n": km_df.shape[0], "n_low": counts["low"], "n_middle": counts["middle"], "n_high": counts["high"],
        "events_low": events["low"], "events_middle": events["middle"], "events_high": events["high"],
        **diagnostics,
        "pval_logrank_nominal": p_value,
        "pval_adj_bh_all_patient_screen": q_value,
        "filter_reason": filter_reason,
    }

km_results = []
if quantile_results_df.empty:
    print("No features passed the tertile survival screen.")
else:
    method = "tertile_even"
    method_screen = quantile_results_df.loc[quantile_results_df["method"] == method].sort_values("pval_logrank_global")
    top_feature_row = method_screen.iloc[0]
    best_feature = top_feature_row["feature"]
    best_feature_q = top_feature_row.get("pval_adj_bh", np.nan)
    feature_title = clean_feature_label(best_feature)
    grouped_feature_df, grouped_feature_diagnostics = add_global_quantile_groups_for_feature(
        spatial_clinical_for_survival,
        best_feature,
        method,
    )
    print(f"Top feature: {feature_title} ({best_feature})")
    print("All patients report the all-feature BH-FDR q-value; LUAD/LUSC p-values are nominal subgroup log-rank tests.")

    fig, ax = plt.subplots(figsize=(5.2, 4.2))
    km_results.append(plot_km_quantile(
        ax,
        grouped_feature_df,
        grouped_feature_diagnostics,
        best_feature,
        "All patients",
        tumor_type=None,
        q_value=best_feature_q,
    ))
    fig.suptitle(f"{feature_title} spatial interaction", fontsize=13, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.show()

    subtype_cohorts = [("LUAD", "Adenocarcinoma"), ("LUSC", "Squamous cell carcinoma")]
    fig, axes = plt.subplots(1, len(subtype_cohorts), figsize=(10.5, 4.2), sharey=True)
    for ax, (title, tumor_type) in zip(axes, subtype_cohorts):
        km_results.append(plot_km_quantile(
            ax,
            grouped_feature_df,
            grouped_feature_diagnostics,
            best_feature,
            title,
            tumor_type=tumor_type,
            q_value=None,
        ))
    fig.suptitle(f"{feature_title} spatial interaction by histology", fontsize=13, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.show()

km_results_df = pd.DataFrame(km_results)
display(km_results_df)
# Out:
# Top feature: Neutrophils vs. hypoxic tCAF (final_cell_type_neutrophils_to_final_cell_type_hypoxic tCAF)
# All patients report the all-feature BH-FDR q-value; LUAD/LUSC p-values are nominal subgroup log-rank tests.
#          cohort               tumor_type  \
# 0  All patients                      All
# 1          LUAD           Adenocarcinoma
# 2          LUSC  Squamous cell carcinoma
#
#                                              feature    n  n_low  n_middle  \
# 0  final_cell_type_neutrophils_to_final_cell_type...  159     53        53
# 1  final_cell_type_neutrophils_to_final_cell_type...   71     21        27
# 2  final_cell_type_neutrophils_to_final_cell_type...   74     25        23
#
#    n_high  events_low  events_middle  events_high      q33       q50  \
# 0      53        48.0           37.0         38.0 -0.52538 -0.310235
# 1      23        19.0           21.0         14.0 -0.52538 -0.310235
# 2      26        22.0           13.0         22.0 -0.52538 -0.310235
#
#         q67  pval_logrank_nominal  pval_adj_bh_all_patient_screen  \
# 0 -0.111719              0.000007                        0.002256
# 1 -0.111719              0.002974                             NaN
# 2 -0.111719              0.000311                             NaN
#
#   filter_reason
# 0        tested
# 1        tested
# 2        tested

# %% [markdown]
# ## Adjusted Multivariable Cox PH Model
#
# The tertile split above is only used to screen candidate interaction variables. The Cox model uses the raw continuous spatial interaction index for the top screened feature and adjusts for Age, Stage, Grade, Gender, and Smoking. Stage and Grade are treated as continuous numeric covariates. Chemo and radiation are included only when they have enough non-missing contrast in the selected feature subset.

# %%
def load_patient_clinical_covariates():
    clinical_covariates = ["Age", "Gender", "Stage", "Grade", "Smok", "Chemo", "Radio"]
    cox_clinical_data = pd.read_csv(CLINICAL_PATH)
    cox_clinical_data = cox_clinical_data.loc[cox_clinical_data["Patient_ID"] != "Control"].copy()
    cox_clinical_data = cox_clinical_data.loc[~cox_clinical_data["NeoAdj"].isna()].copy()
    cox_clinical_data = cox_clinical_data.loc[cox_clinical_data["NeoAdj"] != "NeoAdjuvantTherapy"].reset_index(drop=True)
    cox_clinical_data = cox_clinical_data[["Patient_ID"] + clinical_covariates].drop_duplicates()

    clinical_conflicts = cox_clinical_data.groupby("Patient_ID")[clinical_covariates].nunique(dropna=False)
    clinical_conflicts = clinical_conflicts[(clinical_conflicts > 1).any(axis=1)]
    print(f"Patients with ROI-level clinical covariate conflicts: {len(clinical_conflicts)}")

    cox_clinical_data = cox_clinical_data.drop_duplicates(subset="Patient_ID", keep="first").reset_index(drop=True)
    for col in clinical_covariates:
        cox_clinical_data[col] = pd.to_numeric(cox_clinical_data[col], errors="coerce")
    return cox_clinical_data


def select_default_cox_feature(screen_df: pd.DataFrame):
    if screen_df.empty:
        raise RuntimeError("No screened features are available for Cox modeling.")
    top_row = screen_df.sort_values("pval_logrank_global").iloc[0]
    return str(top_row["feature"]), str(top_row["method"]), float(top_row["pval_logrank_global"])


def run_adjusted_continuous_cox(data: pd.DataFrame, clinical_df: pd.DataFrame, feature: str):
    cox_df = data[["Patient_ID", "OS", "Ev.O", feature]].merge(clinical_df, how="left", on="Patient_ID")
    clinical_covariates = ["Age", "Gender", "Stage", "Grade", "Smok", "Chemo", "Radio"]
    print(f"Patients before dropping missing values: {cox_df['Patient_ID'].nunique()}")
    print("Missing values before Cox model:")
    display(cox_df[["OS", "Ev.O", feature] + clinical_covariates].isna().sum().to_frame("n_missing"))

    base_covariates = [feature, "Age", "Stage", "Grade", "Gender", "Smok"]
    optional_covariates = []
    therapy_decisions = []
    feature_nonmissing = cox_df[feature].notna()
    for therapy_col in ["Chemo", "Radio"]:
        therapy_counts = cox_df.loc[feature_nonmissing, therapy_col].value_counts(dropna=True)
        missing_frac = cox_df.loc[feature_nonmissing, therapy_col].isna().mean()
        include_therapy = missing_frac <= 0.30 and len(therapy_counts) >= 2 and therapy_counts.min() >= 10
        if include_therapy:
            optional_covariates.append(therapy_col)
        therapy_decisions.append(f"{therapy_col}: include={include_therapy}, missing={missing_frac:.1%}, counts={therapy_counts.to_dict()}")

    print("Therapy covariate decisions:")
    for decision in therapy_decisions:
        print(decision)

    cox_covariates = base_covariates + optional_covariates
    cox_model_df = cox_df[["OS", "Ev.O"] + cox_covariates].dropna().copy()

    categorical_covariates = ["Gender", "Smok"] + optional_covariates
    for col in categorical_covariates:
        cox_model_df[col] = cox_model_df[col].astype("category")

    cox_model_df = pd.get_dummies(cox_model_df, columns=categorical_covariates, drop_first=True, dtype=float)
    covariate_cols = [col for col in cox_model_df.columns if col not in ["OS", "Ev.O"]]
    nonconstant_cols = [col for col in covariate_cols if cox_model_df[col].nunique(dropna=True) > 1]
    cox_model_df = cox_model_df[["OS", "Ev.O"] + nonconstant_cols]

    print(f"Patients in Cox model after complete-case filtering: {cox_model_df.shape[0]}")
    print(f"Events in Cox model: {int(cox_model_df['Ev.O'].sum())}")

    cph = CoxPHFitter()
    cph.fit(cox_model_df, duration_col="OS", event_col="Ev.O")

    summary = cph.summary.reset_index().rename(columns={"covariate": "variable"})
    summary = summary[["variable", "coef", "exp(coef)", "exp(coef) lower 95%", "exp(coef) upper 95%", "p"]].copy()
    summary.insert(0, "feature", feature)
    summary.insert(1, "n_model", cox_model_df.shape[0])
    summary.insert(2, "events_model", int(cox_model_df["Ev.O"].sum()))
    summary["therapy_decisions"] = "; ".join(therapy_decisions)
    return summary, cph

# %%
patient_covariates = load_patient_clinical_covariates()

cox_feature, cox_feature_source_method, cox_feature_screen_pval = select_default_cox_feature(quantile_results_df)
print(f"Default Cox feature from top quantile screen: {cox_feature}")
print(f"Source method: {cox_feature_source_method}; global log-rank p = {cox_feature_screen_pval:.3g}")

cox_summary_df, cph = run_adjusted_continuous_cox(spatial_clinical_for_survival, patient_covariates, cox_feature)
display(cox_summary_df)
# Out:
# Patients with ROI-level clinical covariate conflicts: 0
# Default Cox feature from top quantile screen: final_cell_type_neutrophils_to_final_cell_type_hypoxic tCAF
# Source method: tertile_even; global log-rank p = 6.5e-06
# Patients before dropping missing values: 953
# Missing values before Cox model:
#                                                     n_missing
# OS                                                          0
# Ev.O                                                        0
# final_cell_type_neutrophils_to_final_cell_type_...        794
# Age                                                        10
# Gender                                                     10
# Stage                                                      10
# Grade                                                      10
# Smok                                                        0
# Chemo                                                       0
# Radio                                                       0
# Therapy covariate decisions:
# Chemo: include=False, missing=0.0%, counts={0.0: 159}
# Radio: include=False, missing=0.0%, counts={0.0: 159}
# Patients in Cox model after complete-case filtering: 158
# Events in Cox model: 123
#                                              feature  n_model  events_model  \
# 0  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 1  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 2  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 3  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 4  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 5  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 6  final_cell_type_neutrophils_to_final_cell_type...      158           123
# 7  final_cell_type_neutrophils_to_final_cell_type...      158           123
#
#                                             variable      coef  exp(coef)  \
# 0  final_cell_type_neutrophils_to_final_cell_type... -0.564285   0.568767
# 1                                                Age  0.032238   1.032763
# 2                                              Stage  0.273470   1.314518
# 3                                              Grade -0.024284   0.976008
# 4                                         Gender_2.0 -0.117284   0.889332
# 5                                           Smok_1.0  0.059845   1.061672
# 6                                           Smok_2.0 -1.064126   0.345029
# 7                                           Smok_3.0 -0.003333   0.996673
#
#    exp(coef) lower 95%  exp(coef) upper 95%         p  \
# 0             0.378435             0.854826  0.006637
# 1             1.011545             1.054426  0.002337
# 2             1.157926             1.492287  0.000024
# 3             0.697378             1.365962  0.887400
# 4             0.594463             1.330464  0.568223
# 5             0.527221             2.137906  0.866923
# 6             0.043144             2.759285  0.315788
# 7             0.461506             2.152424  0.993231
#
#                                    therapy_decisions
# 0  Chemo: include=False, missing=0.0%, counts={0....
# 1  Chemo: include=False, missing=0.0%, counts={0....
# 2  Chemo: include=False, missing=0.0%, counts={0....
# 3  Chemo: include=False, missing=0.0%, counts={0....
# 4  Chemo: include=False, missing=0.0%, counts={0....
# 5  Chemo: include=False, missing=0.0%, counts={0....
# 6  Chemo: include=False, missing=0.0%, counts={0....
# 7  Chemo: include=False, missing=0.0%, counts={0....

# %% [markdown]
# ## Forest Plot For Continuous Cox Model
#
# The forest plot uses author-defined clinical labels from `00_prepare_clinicaldata.Rmd`: Gender 1 = male, Gender 2 = female; smoking 0 = never, 1 = current, 2 = former, 3 = unknown. Point fill indicates whether the fitted coefficient is positive or negative, and point outline indicates whether the nominal Cox p-value is below 0.05.

# %%
if cox_summary_df.empty:
    print("No Cox summary available for forest plot.")
else:
    plot_df = cox_summary_df.copy()
    plot_df["label"] = plot_df["variable"].map(lambda variable: clean_cox_variable_label(variable, cox_feature))
    plot_df["coef_positive"] = plot_df["coef"] > 0
    plot_df["p_lt_0.05"] = plot_df["p"] < 0.05
    plot_df = plot_df.sort_values("exp(coef)").reset_index(drop=True)
    y_pos = np.arange(plot_df.shape[0])

    deep = sns.color_palette("deep", 10)
    sign_colors = {True: deep[0], False: deep[3]}
    sig_edge_colors = {True: "black", False: "0.70"}

    fig, ax = plt.subplots(figsize=(9.2, max(3.2, 0.42 * plot_df.shape[0])))
    for y, (_, row) in zip(y_pos, plot_df.iterrows()):
        hr = row["exp(coef)"]
        lower = row["exp(coef) lower 95%"]
        upper = row["exp(coef) upper 95%"]
        ax.errorbar(
            hr,
            y,
            xerr=[[hr - lower], [upper - hr]],
            fmt="o",
            markersize=7,
            markerfacecolor=sign_colors[row["coef_positive"]],
            markeredgecolor=sig_edge_colors[row["p_lt_0.05"]],
            markeredgewidth=1.8,
            ecolor="0.55",
            elinewidth=1.3,
            capsize=3,
            zorder=3,
        )

    ax.axvline(1, color="0.25", linestyle="--", linewidth=1)
    ax.set_xscale("log")
    ax.set_yticks(y_pos)
    ax.set_yticklabels(plot_df["label"])
    ax.set_xlabel("Hazard ratio (log scale)")
    ax.set_title(f"Adjusted Cox PH model\n{clean_feature_label(cox_feature)} interaction index", fontsize=12, fontweight="bold")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    sign_handles = [
        plt.Line2D([0], [0], marker="o", linestyle="", markerfacecolor=sign_colors[True], markeredgecolor="black", markersize=7, label="coef > 0"),
        plt.Line2D([0], [0], marker="o", linestyle="", markerfacecolor=sign_colors[False], markeredgecolor="black", markersize=7, label="coef <= 0"),
    ]
    sig_handles = [
        plt.Line2D([0], [0], marker="o", linestyle="", markerfacecolor="white", markeredgecolor=sig_edge_colors[True], markeredgewidth=1.8, markersize=7, label="p < 0.05"),
        plt.Line2D([0], [0], marker="o", linestyle="", markerfacecolor="white", markeredgecolor=sig_edge_colors[False], markeredgewidth=1.8, markersize=7, label="p >= 0.05"),
    ]
    legend1 = ax.legend(handles=sign_handles, title="Coefficient sign", frameon=False, loc="upper left", bbox_to_anchor=(1.02, 1.00), borderaxespad=0)
    ax.add_artist(legend1)
    ax.legend(handles=sig_handles, title="Nominal Cox p", frameon=False, loc="upper left", bbox_to_anchor=(1.02, 0.55), borderaxespad=0)

    fig.subplots_adjust(right=0.72)
    plt.show()
    display(plot_df[["label", "coef", "exp(coef)", "exp(coef) lower 95%", "exp(coef) upper 95%", "p", "coef_positive", "p_lt_0.05"]])
# Out:
#                                             label      coef  exp(coef)  \
# 0                                   former smoker -1.064126   0.345029
# 1  Neutrophils vs. hypoxic tCAF interaction index -0.564285   0.568767
# 2                                          female -0.117284   0.889332
# 3                                           Grade -0.024284   0.976008
# 4                                 smoking unknown -0.003333   0.996673
# 5                                             Age  0.032238   1.032763
# 6                                  current smoker  0.059845   1.061672
# 7                                           Stage  0.273470   1.314518
#
#    exp(coef) lower 95%  exp(coef) upper 95%         p  coef_positive  \
# 0             0.043144             2.759285  0.315788          False
# 1             0.378435             0.854826  0.006637          False
# 2             0.594463             1.330464  0.568223          False
# 3             0.697378             1.365962  0.887400          False
# 4             0.461506             2.152424  0.993231          False
# 5             1.011545             1.054426  0.002337           True
# 6             0.527221             2.137906  0.866923           True
# 7             1.157926             1.492287  0.000024           True
#
#    p_lt_0.05
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7       True
